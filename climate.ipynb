# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

# %%
df = pd.read_csv("Indian_Climate_Dataset_2024_2025.csv")

# %%
df.head(5)
# Out:
#          Date       City        State  Temperature_Max (°C)  \
# 0  2024-01-01     Mumbai  Maharashtra                  32.5
# 1  2024-01-01      Delhi        Delhi                  25.4
# 2  2024-01-01  Bengaluru    Karnataka                  37.2
# 3  2024-01-01    Chennai   Tamil Nadu                  37.2
# 4  2024-01-01    Kolkata  West Bengal                  27.4
#
#    Temperature_Min (°C)  Temperature_Avg (°C)  Humidity (%)  Rainfall (mm)  \
# 0                  18.0                  25.2          77.6            0.0
# 1                  10.7                  18.1          84.1            0.0
# 2                  30.8                  34.0          49.0            3.7
# 3                  30.4                  33.8          34.2            9.5
# 4                  17.5                  22.5          32.2            9.1
#
#    Wind_Speed (km/h)  AQI  AQI_Category  Pressure (hPa)  Cloud_Cover (%)
# 0                3.3  259          Poor          1020.3             62.1
# ...

# %%
df.tail(3)
# Out:
#             Date     City           State  Temperature_Max (°C)  \
# 7307  2025-12-31   Jaipur       Rajasthan                  44.2
# 7308  2025-12-31  Lucknow   Uttar Pradesh                  43.7
# 7309  2025-12-31   Bhopal  Madhya Pradesh                  37.8
#
#       Temperature_Min (°C)  Temperature_Avg (°C)  Humidity (%)  Rainfall (mm)  \
# 7307                  37.6                  40.9          74.8            1.2
# 7308                  35.3                  39.5          50.3            0.0
# 7309                  25.8                  31.8          53.7            0.0
#
#       Wind_Speed (km/h)  AQI  AQI_Category  Pressure (hPa)  Cloud_Cover (%)
# 7307               20.5  329     Very Poor          1006.4             80.0
# 7308                7.3   80  Satisfactory          1011.6             45.9
# 7309               24.0  157      Moderate           996.7             21.4

# %%
df.shape
# Out:
# (7310, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7310 entries, 0 to 7309
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  7310 non-null   object
#  1   City                  7310 non-null   object
#  2   State                 7310 non-null   object
#  3   Temperature_Max (°C)  7310 non-null   float64
#  4   Temperature_Min (°C)  7310 non-null   float64
#  5   Temperature_Avg (°C)  7310 non-null   float64
#  6   Humidity (%)          7310 non-null   float64
#  7   Rainfall (mm)         7310 non-null   float64
#  8   Wind_Speed (km/h)     7310 non-null   float64
#  9   AQI                   7310 non-null   int64
#  10  AQI_Category          7310 non-null   object
#  11  Pressure (hPa)        7310 non-null   float64
#  12  Cloud_Cover (%)       7310 non-null   float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 742.6+ KB

# %%
df.describe()
# Out:
#        Temperature_Max (°C)  Temperature_Min (°C)  Temperature_Avg (°C)  \
# count           7310.000000           7310.000000           7310.000000
# mean              34.952161             25.006402             29.980192
# std                5.781372              6.476264              5.966698
# min               25.000000             10.100000             17.600000
# 25%               30.000000             19.900000             25.000000
# 50%               34.900000             25.000000             30.000000
# 75%               40.000000             30.000000             35.000000
# max               45.000000             39.800000             42.300000
#
#        Humidity (%)  Rainfall (mm)  Wind_Speed (km/h)          AQI  \
# count   7310.000000    7310.000000        7310.000000  7310.000000
# mean      62.653516       8.231300          13.522763   193.759508
# std       18.680171      17.758208           6.562729    89.182569
# ...

# %%
df.dtypes
# Out:
# Date                     object
# City                     object
# State                    object
# Temperature_Max (°C)    float64
# Temperature_Min (°C)    float64
# Temperature_Avg (°C)    float64
# Humidity (%)            float64
# Rainfall (mm)           float64
# Wind_Speed (km/h)       float64
# AQI                       int64
# AQI_Category             object
# Pressure (hPa)          float64
# Cloud_Cover (%)         float64
# dtype: object

# %%
plt.figure(figsize=(8,6))
sns.histplot(df["Temperature_Max (°C)"],bins = 10)
plt.title("Distribution of Max Temperature")
plt.show()

# %%
df["Temperature_Max (°C)"].min()
# Out:
# np.float64(25.0)

# %%
df["City"][df["Temperature_Max (°C)"]==25]
# Out:
# 1527       Jaipur
# 1634      Kolkata
# 1656    Ahmedabad
# 2353      Chennai
# 2695    Hyderabad
# 2724      Kolkata
# 3363      Chennai
# 3734      Kolkata
# 3794      Kolkata
# 3972    Bengaluru
# 4082    Bengaluru
# 4826    Ahmedabad
# 4907       Jaipur
# 5020       Mumbai
# 5057       Jaipur
# 5369       Bhopal
# 5480       Mumbai
# 6510       Mumbai
# 6783      Chennai
# 7020       Mumbai
# 7023      Chennai
# Name: City, dtype: object

# %%
df["City"][df["Temperature_Max (°C)"]==25].unique()
# Out:
# array(['Jaipur', 'Kolkata', 'Ahmedabad', 'Chennai', 'Hyderabad',
#        'Bengaluru', 'Mumbai', 'Bhopal'], dtype=object)

# %%
df.columns
# Out:
# Index(['Date', 'City', 'State', 'Temperature_Max (°C)', 'Temperature_Min (°C)',
#        'Temperature_Avg (°C)', 'Humidity (%)', 'Rainfall (mm)',
#        'Wind_Speed (km/h)', 'AQI', 'AQI_Category', 'Pressure (hPa)',
#        'Cloud_Cover (%)'],
#       dtype='object')

# %%
df['Date'].max()
# Out:
# '2025-12-31'

# %%
df['Date'].min()
# Out:
# '2024-01-01'

# %%
# It means we have a data of around two years

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['month'] = df['Date'].dt.month
df['year'] = df['Date'].dt.year

# %%
df.head()
# Out:
#         Date       City        State  Temperature_Max (°C)  \
# 0 2024-01-01     Mumbai  Maharashtra                  32.5
# 1 2024-01-01      Delhi        Delhi                  25.4
# 2 2024-01-01  Bengaluru    Karnataka                  37.2
# 3 2024-01-01    Chennai   Tamil Nadu                  37.2
# 4 2024-01-01    Kolkata  West Bengal                  27.4
#
#    Temperature_Min (°C)  Temperature_Avg (°C)  Humidity (%)  Rainfall (mm)  \
# 0                  18.0                  25.2          77.6            0.0
# 1                  10.7                  18.1          84.1            0.0
# 2                  30.8                  34.0          49.0            3.7
# 3                  30.4                  33.8          34.2            9.5
# 4                  17.5                  22.5          32.2            9.1
#
#    Wind_Speed (km/h)  AQI  AQI_Category  Pressure (hPa)  Cloud_Cover (%)  \
# 0                3.3  259          Poor          1020.3             62.1
# ...

# %%
df2 = df[df["year"]==2025]
df3 = df[df['year']==2024]

# %%
sns.barplot(df2,x="month",y='Temperature_Max (°C)')
plt.show()

# %%
sns.barplot(df3,x="month",y='Temperature_Max (°C)',color='green')
plt.show()

# %%
df_Maharashtra = df[df['State']=='Maharashtra']

# %%
df_Maharashtra
# Out:
#            Date    City        State  Temperature_Max (°C)  \
# 0    2024-01-01  Mumbai  Maharashtra                  32.5
# 10   2024-01-02  Mumbai  Maharashtra                  25.6
# 20   2024-01-03  Mumbai  Maharashtra                  37.8
# 30   2024-01-04  Mumbai  Maharashtra                  26.0
# 40   2024-01-05  Mumbai  Maharashtra                  27.1
# ...         ...     ...          ...                   ...
# 7260 2025-12-27  Mumbai  Maharashtra                  25.5
# 7270 2025-12-28  Mumbai  Maharashtra                  41.4
# 7280 2025-12-29  Mumbai  Maharashtra                  37.3
# 7290 2025-12-30  Mumbai  Maharashtra                  38.5
# 7300 2025-12-31  Mumbai  Maharashtra                  37.5
#
#       Temperature_Min (°C)  Temperature_Avg (°C)  Humidity (%)  Rainfall (mm)  \
# 0                     18.0                  25.2          77.6            0.0
# 10                    14.3                  19.9          50.4            0.0
# ...

# %%
df_Maharashtra['City'].unique()
# Out:
# array(['Mumbai'], dtype=object)

# %%
df_Punjab = df[df['State']=='Punjab']

# %%
df_Punjab['City'].unique()
# Out:
# array([], dtype=object)

# %%
df['State'].unique()
# Out:
# array(['Maharashtra', 'Delhi', 'Karnataka', 'Tamil Nadu', 'West Bengal',
#        'Telangana', 'Gujarat', 'Rajasthan', 'Uttar Pradesh',
#        'Madhya Pradesh'], dtype=object)

# %%
# So there is no any data of Punjab in the data set

# %%
df_Delhi = df[df['State'] == 'Delhi']
